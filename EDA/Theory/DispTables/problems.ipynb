# %% [markdown]
# # I. Ejercicios con direccionamiento abierto
#
# Aunque no vayamos a ver la implementación de las tablas de dispersión con resolución de colisiones mediante direccionamiento abierto (también llamado *open addressing*), es sencillo ver cómo funcionan.
#
# ---
#
# ### Ejercicio 1: Inserción con Linear Probing
#
# Crea una tabla de dispersión con direccionamiento abierto y con $N = 10$ cubetas. Todas las cubetas estarán, inicialmente, a un valor especial indicando libre (puedes denotarlo dejándolo en blanco).
#
# Vamos a suponer que en la tabla guardamos únicamente claves (es decir, sería parecido a un conjunto o *set*, ya que no se asocia un valor a cada clave).
#
# Dibuja el resultado de insertar sobre dicha tabla, y en este orden, los elementos:
#
# $$[5, 15, 26, 7, 35, 2, 1]$$
#
# Usando como función de dispersión:
#
# $$f(x) = x \pmod N$$
#
# Si se produce una colisión (si una casilla está ya ocupada), haremos ***linear probing***, lo que significa que pasaremos a la casilla siguiente (inferior si lo has dibujado en vertical) de manera circular. Es decir, la casilla que sigue al índice $x$ está en el índice:
#
# $$(x + 1) \pmod N$$
#
# ---
#
# ### Ejercicio 2: Análisis de Búsqueda y Peor Caso
#
# Para el ejemplo que acabas de calcular:
#
# 1. **¿Cuántos elementos hay que comparar, en el peor caso, cuando buscamos un elemento?**
# 2. **Pon un ejemplo** de un elemento a buscar y muestra los objetos de la tabla con los que lo compararíamos hasta determinar que el elemento buscado está o no está en el conjunto.

# %%
class DispersionTable:
    pass

# %% [markdown]
# # II. Ejercicios sobre funciones de dispersión
#
# ---
#
# ### Ejercicio 2
# **Señala cuáles de las siguientes afirmaciones sobre el método `__hash__` (equivalentemente, la función `hash()`) son correctas para los objetos de tipo *hashable*:**
#
# * **a)** Al aplicarse a objetos distintos (según `==`) puede devolver el mismo entero.
# * **b)** Al aplicarse a objetos distintos (según `==`) siempre devuelve un entero distinto.
#
#
# ---
#
# ### Ejercicio 3
# **Selecciona de entre las siguientes opciones aquellas (puede que más de una) que sean ciertas, para valores *hashable* que además sean de tipo *built-in* en Python:**
#
# * **a)** Para dos claves `k1` y `k2` tales que `k1 == k2`, la función `hash()` da siempre el mismo valor.
# * **b)** Para dos claves `k1` y `k2` tales que `k1 != k2`, la función `hash()` da siempre distinto valor.
# * **c)** Para dos claves `k1` y `k2` que tienen el mismo valor hash, se cumple necesariamente que `k1 == k2`.
# * **d)** Para dos claves `k1` y `k2` que tienen distinto valor hash, se cumple necesariamente que `k1 != k2`.
#
#
# ---
#
# ### Ejercicio 4
# **Ya sabes que las clases definidas por el usuario son, en principio, *hashable*. Sin embargo, al igual que ocurre con el método `__eq__`, se limitan a considerar únicamente la identidad del objeto sin consultar ninguno de sus atributos. Considera la siguiente clase y las variables que creamos con ella:**
#
# ```python
# class Ejemplo:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
# x = Ejemplo(1, 2)
# y = Ejemplo(1, 2)
# z = y
#
# ```
#
# e indica cual de las siguientes afirmaciones es cierta:
# * **a)** x == x da siempre True,
# * **b)** x == y es falso,
# * **c)** normalmente hash(x)!= hash(y)
# * **d)** se cumple siempre que hash(y)== hash(z)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 5
#
# Si modificáramos la clase `Ejemplo` para definir el método `__eq__`, resulta que la función `hash()` (y el método `__hash__`) no estarían definidos (Python 3 considera *unhashable* cualquier clase definida por el usuario que redefina `__eq__` pero no redefina `__hash__`), con lo que el siguiente código daría error:
#
# ```python
# class Ejemplo:
#
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#     def __eq__(self, other):
#         return (
#             isinstance(other, Ejemplo)
#             and self.x == other.x
#             and self.y == other.y
#         )
#
#
# x = Ejemplo(1, 2)
# y = Ejemplo(1, 2)
#
# print(x == y)  # da True
# print(hash(x))  # dispara un error o excepción...
# ```
#
#
# Se pide implementar el metodo __hash__ para que tenga en cuenta los atributos x e y. Como consejo (ver apuntes), cuando hay mas de un atributo se puede usar la funcion hash aplicada a una tupla.

# %%
# Respuesta

def hash_func():
    pass

# %% [markdown]
# ## III. Ejercicios con `SeparateChainingHashTable`
#
# En algunos ejercicios debes modificar la clase `SeparateChainingHashTable` que tienes disponible en el fichero `SeparateChainingHashTable.py` en la página de Lessons del tema 1.
#
# ---
#
# ### Ejercicio 6
# Implementa el método `esOk` en la clase `SeparateChainingHashTable` que no recibe argumentos y que comprueba que todas las claves guardadas estén en la cubeta adecuada (la que nos devuelve el método `_hash_function`). Si todas las claves están donde toca, el método devolverá `True`, pero si encuentra una entrada en una cubeta equivocada parará inmediatamente devolviendo `False`.
#
# ---
#
# ### Ejercicio 7
# Implementa un método `keyCollisions` en la clase `SeparateChainingHashTable` que reciba como argumento una clave (que no necesariamente ha de estar guardada en el objeto) y devuelva una lista de todas las claves guardadas en el objeto que colisionan con la clave recibida como argumento.
#
# ---
#
# ### Ejercicio 8
# Implementa un método llamado `filter` en la clase `SeparateChainingHashTable` que reciba como argumento una función `f` y que no devuelva nada. La función recibida `f` se puede ejecutar cuando se precise y recibirá como único argumento una clave del diccionario, devolviendo al final un booleano (`True` o `False`).
#
# Tras ejecutar el método `filter`, se deben haber eliminado todas las entradas de la tabla de dispersión para las que la función `f` ha devuelto `False` cuando se ha aplicado a la clave. Dicho de otra manera, debe preservar únicamente las entradas de la tabla de dispersión para las que la función `f` ha devuelto `True`.
#
# ---
#
# ### Ejercicio 9
# Implementa un método llamado `mayorLongitud` en la clase `SeparateChainingHashTable` que no recibe nada y devuelve la mayor longitud de cualquier lista presente en alguna de sus cubetas (también llamadas casillas o *slots*). Este valor sirve para saber el número de comparaciones a realizar, durante una búsqueda, en el peor caso.
#
# ---
#
# ### Ejercicio 10
# Implementa el método `__eq__` en la clase `SeparateChainingHashTable` de modo que recibe un único argumento:
# - Si el argumento no es una instancia de la clase `SeparateChainingHashTable`, devolveremos `False`.
# - En caso contrario, devolveremos `True` si la tabla recibida tiene el mismo número de elementos que el propio objeto y, además, todos los pares `(clave, valor)` de una tabla están en la otra.
# - En otro caso, se devolverá `False`.
#
# > **Observación:** Se puede devolver `True` aunque ambas tablas tengan un número distinto de cubetas, siempre y cuando tengan los mismos elementos.
#
# ---
#
# ### Ejercicio 11
# Implementa el método `__samekeys__` en la clase `SeparateChainingHashTable` de modo que recibe un único argumento:
# - Si el argumento no es una instancia de la clase `SeparateChainingHashTable`, devolveremos `False`.
# - En caso contrario, devolveremos `True` si la tabla recibida tiene el mismo número de elementos que el propio objeto y, además, todas las claves de una están en la otra (si no, se devolverá `False`).
#
# > **Observación:** `__samekeys__` es muy similar a `__eq__`, salvo que solamente comprueba claves y no los valores asociados a las mismas.

# %% [markdown]
# ## IV. Otros ejercicios (histogramas de ocupación, ...)
#
# ---
#
# ### Ejercicio 12
# Queremos guardar en una tabla de dispersión (con resolución de colisiones por encadenamiento o *separate chaining*) un total de 100 claves diferentes (con sus respectivos valores). Queremos que la tabla nos quede con un factor de carga $FC = 0.75$ (o lo más cercano posible) ¿Cuál es la mejor elección para el número de cubetas $N$ para tal efecto? (justifica o razona la respuesta)
#
# - **a)** 100
# - **b)** 101
# - **c)** 211
# - **d)** 133
# - **e)** 137
#
# ---
#
# ### Ejercicio 13
# Inserta los números (son claves, ignora los valores asociados) **9, 7, 3, 17, 18, 16 y 12** en una tabla de dispersión con *separate chaining* usando como función de dispersión $f(x) = x \% N$. Calcula el factor de carga y dibuja el histograma de ocupación:
#
# - **a)** Cuando $N = 5$ cubetas.
# - **b)** Cuando $N = 10$ cubetas.
#
# ---
#
# ### Ejercicio 14
# Dos ficheros $F1$ y $F2$, ambos con el mismo número de palabras, se dispersan en sendas tablas de dispersión, ambas de la misma dimensión, y usando la misma función de dispersión. Se mide la ocupación de las cubetas en ambos casos, y se obtiene:
#
# | Métrica | $F1$ | $F2$ |
# | :--- | :---: | :---: |
# | **Media** | 4.25 | 4.25 |
# | **Desviación típica** | 0.84 | 16.73 |
#
# ¿Para cuál de los dos ficheros es más adecuada la función de dispersión usada? Justifica la respuesta.
#
# ---
#
# ### Ejercicio 15
# ¿Qué supondría en una tabla de dispersión con $N = 1001$ cubetas calcular la longitud de cada cubeta y que esta longitud tuviese media $k = 100$ y varianza 0?
#
# ---
#
# ### Ejercicio 16
# Inserta los números **17, 29, 50, 24, 46, 35, 15, 14, 11, 32, 8, 44 y 25** en una tabla de dispersión con *separate chaining* que tiene como función de dispersión $f(x) = x \% N$, siendo $N$ el número de cubetas.
#
# La tabla debe empezar con 5 cubetas y debe doblar ese tamaño cada vez que el factor de carga alcance el valor 2. Dibuja el histograma de ocupación de la tabla resultante.
#
# ---
#
# ### Ejercicio 17
# Sea el siguiente histograma de ocupación de una tabla de dispersión:
#
# **Histograma Inicial**
# ```text
# Nº Cubetas
#     5 ┼
#     4 ┼
#     3 ┼         ┌───┐
#     2 ┼ ┌───┐   │   │
#     1 ┼ │   │┌──┤   │    ┌───┐
#     0 ┴─┴───┴┴──┴───┴────┴───┴───
#         0    1   2    3   4    5  Longitud
#
# - **a)** Indica el número de elementos y de cubetas que tiene la tabla.
# - **b)** Indica si es posible insertar uno o más elementos y que el histograma pase a ser como en la siguiente figura:
#
# Nº Cubetas
#     5 ┼
#     4 ┼         ┌───┐
#     3 ┼         │   │
#     2 ┼ ┌───┐   │   │
#     1 ┼ │   │   │   │    ┌───┐
#     0 ┴─┴───┴───┴───┴────┴───┴───
#         0    1   2    3   4    5  Longitud
#
# > Si no es posible debes razonar por qué no lo es. Si, por el contrario, fuese posible, has de indicar cuántos elementos insertar y en qué cubetas deberían de añadirse. Asume que no se produce redispersión o *rehashing*.
